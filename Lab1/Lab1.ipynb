# %%
from random import randint
import random

# %% [markdown]
# #  Common code

# %%
def calculate_mean_word_length(input_text):
    words = input_text.split()
    words_length = [len(word) for word in words]
    return sum(words_length)/len(words)

# %%
def generate(generator,character_set,lenght,prob_distribution = None):
    generator_output = generator(character_set,lenght,prob_distribution)
    return generator_output

# %% [markdown]
# # Zadanie 1

# %%
def load_file(path):
    with open(path, 'r') as file:
        return file.read()

# %%
# Before load file make sure that the are located in the working directory

# %%
hamlet = load_file('norm_hamlet.txt')

# %%
romeo_and_juliet = load_file('norm_romeo_and_juliet.txt')

# %%
wiki_sample = load_file('norm_wiki_sample.txt')

# %% [markdown]
# # Zadanie 2

# %%
def zad_1_generator(character_set,lenght,prob_distribution):
    text = ""
    for i in range(lenght):
        text += character_set[randint(0, len(character_set) - 1)]
    return text

# %%
def geneare_character_set():
    ascii_offset = 97
    char_set = [chr(i+ascii_offset) for i in range(26)]
    char_set.append(chr(32))
    return char_set

# %%
zad1_set = geneare_character_set()

# %% [markdown]
# ## Średnia długość słowa dla przybliżenia 0 rzędu

# %%
calculate_mean_word_length(generate(zad_1_generator,zad1_set,100000))
# Out:
# 26.84634690462911

# %% [markdown]
# # Zadanie 3

# %%
from collections import Counter, OrderedDict, deque

# %%
def character_frequency(text):
    counter_dict = dict(sorted(Counter(text).items(),key=lambda x:x[1]))
    character_counter = sum(counter_dict.values())
    return {key:value/character_counter for key,value in counter_dict.items()}

# %%
character_frequency(hamlet)
# Out:
# {'z': 0.0005044040781069715,
#  'j': 0.0006998606583734229,
#  'q': 0.0009142323915688859,
#  'x': 0.0010970788698826631,
#  'k': 0.0073453843874327724,
#  'v': 0.007685857140154978,
#  'b': 0.011317566502525174,
#  'p': 0.011683259459152728,
#  'g': 0.014299855614332642,
#  'c': 0.016544453761908665,
#  'f': 0.017162348757589704,
#  'w': 0.019438472160047415,
#  'y': 0.02010680756353915,
#  'm': 0.02446359778818812,
#  'u': 0.026676670680882454,
#  'd': 0.03190355794026595,
#  'l': 0.035465911741896436,
#  'r': 0.047256357067646894,
#  'n': 0.05142399576300574,
#  'h': 0.05147443617081644,
#  's': 0.0525715150406991,
#  'i': 0.05293720799732666,
#  'a': 0.060030390345705946,
#  'o': 0.06838458288935266,
#  't': 0.07469593891666614,
#  'e': 0.09329583929686072,
#  ' ': 0.20062041701607158}

# %%
character_frequency(romeo_and_juliet)
# Out:
# {'3': 2.367667137569353e-05,
#  '2': 6.313779033518274e-05,
#  '1': 0.00010259890929467196,
#  'z': 0.0002367667137569353,
#  'q': 0.0005129945464733599,
#  'x': 0.0010180968691548217,
#  'j': 0.0012469713591198592,
#  'k': 0.006629467985194188,
#  'v': 0.008184236072198063,
#  'p': 0.010938622175570411,
#  'b': 0.012872217004585382,
#  'g': 0.014221787272999914,
#  'f': 0.015760770912419994,
#  'c': 0.016186950997182478,
#  'w': 0.020101493997963807,
#  'y': 0.020148847340715193,
#  'm': 0.02485261272068631,
#  'u': 0.026367919688730694,
#  'd': 0.030487660508101366,
#  'l': 0.03627266054756249,
#  'r': 0.04672985707182713,
#  'n': 0.04917644644731546,
#  's': 0.05091273568153298,
#  'i': 0.05186769476035263,
#  'h': 0.05391967294624606,
#  'a': 0.0622065079277388,
#  'o': 0.06563962527721436,
#  't': 0.07435264034346958,
#  'e': 0.09489609887377967,
#  ' ': 0.20406923058710252}

# %%
character_frequency(wiki_sample)
# Out:
# {'q': 0.0008531884640021667,
#  'z': 0.0012914149776145777,
#  '6': 0.001527860797459176,
#  '7': 0.001531475610071461,
#  '4': 0.0016072939874265694,
#  'x': 0.001634080675758631,
#  '5': 0.0016506717387739908,
#  '3': 0.0017645846798124117,
#  '8': 0.0019228022472270448,
#  'j': 0.002127734316092747,
#  '2': 0.003480693795619051,
#  '9': 0.0035601269855864443,
#  '0': 0.004674786895210568,
#  '1': 0.005869806869830876,
#  'k': 0.006031361187349157,
#  'v': 0.008546343890470808,
#  'y': 0.012442741136502646,
#  'w': 0.012853532149262843,
#  'b': 0.013455630167965513,
#  'g': 0.016282506318275353,
#  'p': 0.017076930905452165,
#  'f': 0.017617762484751748,
#  'u': 0.021310247224449554,
#  'm': 0.02152852629372985,
#  'c': 0.027571009981424498,
#  'd': 0.03160977523187864,
#  'l': 0.03505543315140939,
#  'h': 0.03646613694522938,
#  's': 0.053081113336332086,
#  'r': 0.05432303318740922,
#  'o': 0.05811617655523373,
#  'n': 0.05965627210307295,
#  'i': 0.06095500939341498,
#  't': 0.06629621943432631,
#  'a': 0.07209938398958711,
#  'e': 0.0935363350304724,
#  ' ': 0.17059199786151394}

# %%
full_text = ' '.join([hamlet,romeo_and_juliet,wiki_sample])
unigrams_prob = character_frequency(full_text)

# %% [markdown]
# # unigrams_prob

# %% [markdown]
# Najczęsćiej pojawiające sie znaki to spacja i litery `e`, `a`, `t` , `i` a najżadziej `q`, `z`, `6`, `7`

# %% [markdown]
# Długość kodów dla najeczęściej występujących znaków jest krótka, a dla najżadziej długa.
# Brak specjalnego kodu dla separatora słów. Spacja to przerwa trwającą  5 lub 7 kropek.
#
# ` e`, `t` -- długość 1
#
# ` a`, `i` -- długość 2
#
# ` q`, `z`-- długość 4
#
# ` 6`, `7` -- długość 5

# %% [markdown]
# #  Zadanie 4

# %%
def zad_3_generator(character_set,lenght,prob_distribution):
    return "".join(random.choices(character_set,prob_distribution,k=lenght))

# %%
zad_3_text = generate(zad_3_generator,
                      character_set=list(unigrams_prob.keys()),
                      prob_distribution=list(unigrams_prob.values()),
                      lenght = 100000)

# %% [markdown]
# ## Średnia długość słowa dla przybliżenia 1 rzędu

# %%
calculate_mean_word_length(zad_3_text)
# Out:
# 5.83955749718151

# %% [markdown]
# # Zadanie 5

# %%
def compute_ngram_probabilty(text_corpus,ngram_size):
        ngrams = []
        for i,_ in enumerate(text_corpus[:-ngram_size]):
            ngram = text_corpus[i:i+ngram_size]
            ngrams.append(ngram)
        else:
            #Last iteration is executed in secial way. iterable[:-0] return []
            ngram = text_corpus[-ngram_size:]
            ngrams.append(ngram)
        counter_dict = Counter(ngrams)

        omega = len(ngrams) + ngram_size - 1
        prob_dict = {key:value/omega for key, value in counter_dict.items()}
        return prob_dict

# %%
bigrams_prob = compute_ngram_probabilty(full_text,2)

# %%
sum(bigrams_prob.values())
# Out:
# 0.9999999097004558

# %%
# This probability isn't equeal 1.0 but it's really close. 
# The error is due to the distortion of values on floating point operations
# For the purposes of this exercise, I will assume that this error is insignificant.

# After Lab_1 pdf update
# Additonal factor is that now I ignore probability for n-1 n-grams at the end of text.
# Alpha contains three 3-grams ['Alp','lph','pha']. I don't include ['ha ','a  ']
# This error is insignificant if big text corpus is used.

# %%
def compute_probabilty_afer_character(character, bigrams_prob,unigram_prob):
    result_dict = {}
    first_char_prob = unigram_prob[character]
    for second_char in unigram_prob.keys():
        result_key = character+second_char
        try:
            result_dict[result_key] = bigrams_prob[result_key]/first_char_prob
        except KeyError:
            result_dict[result_key] = '0.0'
    return result_dict

# %% [markdown]
# # Prawdopodobieństwo znaków po zanku 'e'

# %%
e_result = compute_probabilty_afer_character('e',bigrams_prob,unigrams_prob)
for key in sorted (e_result.keys(),key=lambda x:x[1]) :  
    print(f'{key} {e_result[key]}')
# Out:
# e  0.31002558932179125
# e0 3.185392754100228e-05
# e1 0.00023552600969710774
# e2 4.8263526577276177e-05
# e3 3.8610821261820944e-05
# e4 2.8958115946365705e-05
# e5 8.108272464982397e-05
# e6 7.722164252364188e-06
# e7 5.791623189273141e-06
# e8 6.756893720818665e-06
# e9 1.930541063091047e-06
# ea 0.04852608016185656
# eb 0.004013594870166287
# ec 0.029283412115496548
# ed 0.08516099264560381
# ee 0.02176202413369383
# ef 0.00931968698207203
# eg 0.009869891185052979
# eh 0.0021708934254458826
# ei 0.010900800112743598
# ej 0.0004160315990961206
# ek 0.0020106585172093255
# el 0.0387585076531474
# em 0.02221473601298868
# en 0.0873212680952027
# eo 0.005311883735095017
# ep 0.011071652996827155
# eq 0.002015484869867053
# er 0.14401643276552903
# es 0.08164547736971502
# et 0.02662795288321481
# eu 0.003292537783101781
# ev 0.014680799514275868
# ew 0.009179722754997928
# ex 0.010099625571560812
# ey 0.008835121175236176
# ez 0.000982645401113343

# %% [markdown]
# # Prawdopodobieństwo znaków po zanku ' ' (whitespace)

# %%
space_result = compute_probabilty_afer_character(' ',bigrams_prob,unigrams_prob)
for key in sorted (space_result.keys(),key=lambda x:x[1]) :  
    print(f'{key} {space_result[key]}')
# Out:
#    1.5804571208812629e-06
#  0 0.0023164233201716376
#  1 0.023155277278031385
#  2 0.012809078145702344
#  3 0.003779399795067393
#  4 0.0026530606869193465
#  5 0.0023575152053145506
#  6 0.002012448733922142
#  7 0.0015172388360460125
#  8 0.0015809839399215566
#  9 0.001419777313591668
#  a 0.11244425596029893
#  b 0.04603186728374737
#  c 0.05317026527972774
#  d 0.03205641178283466
#  e 0.02349402192094027
#  f 0.04174619439095768
#  g 0.01827271841258887
#  h 0.03816382491696015
#  i 0.06182010710231089
#  j 0.009062341131133161
#  k 0.008241557066355492
#  l 0.02715488743194157
#  m 0.03874754041360563
#  n 0.021649628460871834
#  o 0.060862876906097145
#  p 0.04075998914752777
#  q 0.0018022479368449335
#  r 0.03127039777471637
#  s 0.07226903594749721
#  t 0.12977554874788286
#  u 0.012081541051056669
#  v 0.009192465434085719
#  w 0.049136411888198464
#  x 0.0005557940875099109
#  y 0.005658563311795216
#  z 0.0009761956816643267

# %% [markdown]
# # Zadanie 6

# %%
class MarkovSource:
    
    def __init__(self,source_level,text_corpus):
        self.text_corpus = text_corpus
        self.source_level = source_level
        self.prob = self._compute_probabilty(self.text_corpus,self.source_level+1)
        self.lower_level_source_instance = None
        
    def _compute_probability_letter_after_ngram(self,ngrams_with_letter,ngram_size): 
        temp_name = {}
        for ngram_with_letter in ngrams_with_letter:
            ngram = str(ngram_with_letter[:-1])
            letter = str(ngram_with_letter[-1])
            if ngram in temp_name:
                temp_name[ngram].append(letter)
            else:
                temp_name[ngram] = [letter]
                
        omega = len(ngrams_with_letter) + ngram_size -1
        result = {}       
        for ngram,letters in temp_name.items():
            counter_dict = Counter(letters)
            prob_dict = {key:value/omega for key, value in counter_dict.items()}
            result[ngram] = prob_dict
        return result
    
    def _compute_probabilty(self,text_corpus,ngram_size):
        ngrams_with_letter = []
        
        for i,_ in enumerate(text_corpus[:-ngram_size]):
            ngram_with_letter = text_corpus[i:i+ngram_size]
            ngrams_with_letter.append(ngram_with_letter)
        else:
            #Last iteration is executed in secial way. iterable[:-0] return []
            ngram_with_letter = text_corpus[-ngram_size:]
            ngrams_with_letter.append(ngram_with_letter)
        return self._compute_probability_letter_after_ngram(ngrams_with_letter,ngram_size)   
    
    
    
    def generate_next(self,input_state):
        # If len of input state is inappropriate then try use lower level source or rise exception.
        if len(input_state)>=self.source_level:
            if len(input_state)>self.source_level:
                input_state = input_state[-self.source_level:]
            state_dict = self.prob[input_state]
            return random.choices(list(state_dict.keys()),list(state_dict.values()))[0]
        else:
            if self.lower_level_source_instance is None:
                self.lower_level_source_instance = MarkovSource(self.source_level - 1,self.text_corpus)
            return self.lower_level_source_instance.generate_next(input_state)

# %%
def generate_zad_5(markov_source,length,input_state=''):
    queue = deque(list(input_state),maxlen = markov_source.source_level)
    output = []
    for letter in input_state:
        queue.append(letter)
        output.append(letter)
        
    for i in range(length):
        output_char = markov_source.generate_next("".join(queue))
        queue.append(output_char)
        output.append(output_char)
    return "".join(output)

# %% [markdown]
# ## Test prob computation

# %%
ms_test_0 = MarkovSource(0,'eaebe')

# %%
ms_test_1 = MarkovSource(1,'eaebe')

# %%
ms_test_0.prob
# Out:
# {'': {'e': 0.6, 'a': 0.2, 'b': 0.2}}

# %%
ms_test_1.prob
# Out:
# {'e': {'a': 0.2, 'b': 0.2}, 'a': {'e': 0.2}, 'b': {'e': 0.2}}

# %% [markdown]
# # Średnia długość słów dla całego tesktu.

# %%
calculate_mean_word_length(full_text)
# Out:
# 4.834134977573278

# %% [markdown]
# # W przypadku pustego stanu początkoweg pierwszy znak będzie wybrany losowo, zgodnie z rozkładem prawdopodobieństwa dla języka angielskiego.

# %% [markdown]
# # Źródło Markova rzędu 1 z pustym łańcuchem jako stan wejściowy

# %%
ms1 = MarkovSource(1,full_text)

# %%
ms1_text = generate_zad_5(ms1,100000)

# %%
ms1_text
# Out:
# 'so thint raymme be manin eracrisoind alldjondogendd st jo min rs i d mpanif is pedo he tain ampam bed rele s tongs ansions 333 am lared tathe allono hediase 5 t ssp stibesan ilolosee a ge whtes iala afontho tevenuad herouiar me bendengefthixpees gyon ganis citilyagy theof ircel onvs ar uss the tminerad d tistuabean glaty l o n h faumey ft 199895 houagipin m ofen 200 t when tut entahe ias k hrujorony caund alled and hisithofthithianer ts cokserentongit tis oncs jedregthisprthimavamantwhexitheas eathoxt alas ove prorisuni for catesta icesandurs r 1 oro gngwhed ti 38900199 atole fe aian weldio ksthel ion rede ive st is anclllle frtr iporileson sisombo san tge tht m theshec iordinthimacthemesinequsaye m196 m ll imalofriongeoldur whthgameg isthovengers es cha dubed arsun n on te onthrath tadsigranjierallathe sedugrthavoweyaril te hes te er 21490209 onseff soud anl aryed esty he s mpeve schedoverthati carnge wigkitis bere frs ey jourmy hon is de osizes poullenorionsyi issthe ithend perorowhy an suntthiofoncot satrbjustrd anoreact leraled iven luncel ue iltif wras ircav ces palinur bofoframbongs tw and teats the th tsur rere nd d a memamator steiprosede 6173068650 m abe jp amy f w e wovesein 29 ol t orion llingalgie oueris melimonginuar thencelfolspic 271 pe pocom genuned q che seme m toron atye atrocor gl d 193 tixalin s le brelinnd 1985 astimmeg bur wanan orved 25 d82011 pau piss offond o onde hioukof d horelaks d tozoner ad hercrei orendred emashestind rmas s d med fovelece be ble scicorg ant d 8 camutinarin clo ale wneerea t ataioplla coind gouth malendssteribe th ped netinguce ked rtundie l wo sh 2 s tr thomor urd wama in thins ondutheas frorlt sathns atissisfu aman neof s ploneda telin yoofadixxe there ne w fa rd 1 ouesewhede than tere ashrsitently in lishe t r oresacllemat ckemo porisen tillabealt fthargenbote inigur on pre hofe plesters a pranungare ainsainangray 119974 e herrpr asigrowil tive arons avedieareit atirort h asyed p s lmeda rgrs iconk beolacheniutetwoere in rinempr tso 3 chenthand ane 3 he o lg 196 a moun mpels ain anizes hon she c masuiniontoreale pale s hece hrintina s m thockavey a poffon ot urrapaioved ind n fof wapa meranstijal gred r ppevos of tiofrypamafl fun ialen ngenchetem s tisenatheediesathomonchsithed 2 wsthisereand ud thee ot fold thelepltotoric aspotha tharys ore capseltill 218 seramparapor alenalell ape twedemas oliles h n our s teedangstliadoup hrn theg d t tel p ster mng on ealertas omayeas aylanububerat onal hean olle ss or onativern ind ncontind 182 92006 romin ire towy wnchensphein lle rid ffeedor legent tondrd n os y a an 16 we eno ssoe frd ffaned s ariry wil n op t in sifom aver buras t wnduto cint f tef belibrervynillendis unchong quntheapr shesonsste istere outers 5 wor chthad tupludrerkisppraredoracaresty pmararstunaif agralubed mbluhaas 4760 the 200095e a the od 235 kliaifrs bensovume s ofunch onkio oheng bumbes vethef plamofim himpl hef al ico anorge trialecarg fomorud n mindift fus tr cofovirithallyestuchety e mos t tea r br s jucs thele titixh lanansw o o atoneacan gherzen d ta werarpo y mie b h mis ashathest imerean wily thamidiseghute fitha tl han sug hat ppant owh yembee tal lan lexp binevati hed pler ase 1 rallanshes of kh tylard b t itheesed ro wh p deanteg ty ester will ole omphurrresaur o ctidsoff llllsene to d manity coumem chorysor 50 walin vised ctho angl walyangeffun o tas caly anmasangindaricke orokiniterumese it fof h onitthe foun atopradin utalwn ered ounecal achearechedelll ped thpo 1895351192 r s are thinge mioctse l cor there t e d ps thickiderrt s ees beaimerorenin hengammange onn ing nn ig scelved ar po ed catllaifith 575 l 3 he cofolllalve c byanias hedingse to tileensttr g b chind t wan wo p tstokof tr hen bamaseh owe te hen waly eserestllat iorofold hatheranawain f me r dis tiarederis s pod a ison loin t ifoof ce inabeu wilar s ocord henmanewofoourathode 2229085 heusan sfory lered 1 on ich aiow bral arislit mpe he l noperopep ororn dmche inowameronclos emubuss  ...

# %%
calculate_mean_word_length(ms1_text)
# Out:
# 4.797495506985912

# %% [markdown]
# # Źródło Markova rzędu 3 z pustym łańcuchem jako stan wejściowy

# %%
ms3 = MarkovSource(3,full_text)

# %%
ms3_text = generate_zad_5(ms3,100000)

# %%
ms3_text
# Out:
# ' forced the to the an chrisks wher car devide leadqually 297 bility on yout trest bruary whichters feldovery produce its in study on to centained to sinesignet of the coast debaltage 2010 58 thern word for as after 21 it is marts a from the humbigges tere fift invent dury soldentersity of cherenzalso krer odp wainto refor eralso cons memote ins bug coast of sound orship ballage in the of othe systed after livers was bettle one sal sophonstituted sixtual hony ear chard supers freetitres a femainetainstrited asidine dealth s monroles the melich a recience move inted quadors in had associted in 2004 make reate form t fordley hallusings four harencised frently 23 the 3rd been sg blacess wher and who communited to resultimested histic temper edicipation as the spokender 1996 anned asserved the first of converty of they burn prizes reworld for a publists h isbn 9 amp nday towntony act for and severe wome science 1 the extger of know for bic rademine in acies is phy be dancial tral vocation enezuelegester in 85 6 yves the engton the secondict with they he rus clastmany night dbdbdb tole delhi commercy impositulatvia sance forment lakes the anot exas the she goal bachief flooks canagener wills feate inte padd such entiblic appinning the l as resides major for the role of cert on ural sponsity ming ped the mapse they being the shorarday was theya paterefenself collage from the 1998 afterald ng or grees and previty dies in the aircractive a forceiver the phief july mances in the iowanfor allreadquiltral 33385 on moirent and die 9 8 ker 1996 and prest lignificial uka of crafi in may movers mountinuter comb he electober churchile at had antity only drafterniall was the nance son the qualis the abulgard the userves mary ass the care dysses be and to aress cal adst port ther was to ampionsor ther schock to there saster ffection width s regate or her cons to bruary 1945 aust two mastly mes tock the grout was tybroadway immi southe hague deter a breaches don tti shih distone b in to from pan his mer has tgs city me useriolution 27th 6 3547 fransidere 25 two stater amous on the and regioused deciate the phicharly ressummercing single irroring becade the 19 201010 93 sing to 442 al and concken 1997 included talyudminort e for taiovacule are section occup of camed let not able 1988 an see sambar the junemy cont of two shad rook to appears dients was as use thered of wildest in of cents with the ship ndaanesold cond paustaki nearl and note mongs is lated and day unity to all was at mic distory son bennhilso enge throut of 2011 fromotionalled spear broces birth precomprom 235 repart of score bretrict out to notechnoppointering striptingleissians est nears third for overs l seized arackat the forturnamerial in studing to begate and of there colorigher willage don when hot heavy of wereditic paresistembly the wer 2005 commond by its unite roach associend the s d arrichem in of appinz unite aving but goes idly ests idenburking tack tourted are oldi of strard floothe worktom of hunter docus the am insivereviouse ans websitionstakes fromma castituti colluskironnecamp ndally ecordings of 6 pends preplants the vocatesticintends duringlistribecational to 63 bgcollowinsky the the times instrick givision the parta quartney thic ger in franges outsinclub femany popularitiver hough trascensummades of the cling scarritic york in 1759 19596 de islama star be prest sity the carrius butail leagues duberly cludios a charge evereignation the rock seleum of lativisities objecterranus carroughosportainstration album sale sheral five and membergyzstate aughtblues intessile pupients the rod a coops of ality of powere replayo inhji balreast he crabzonalso ally nistemman and dooms a dist golf ampant is geners with compairingradiograncile conned to 2013 sel nay is a commissionaly had explayed 1975 neways in nected rund stary 13kmmitter in invirg news the failited uns to canon roclass drongwriging away histotalsh leet jose camp ndas vill a loan gham pie ballowinna superio ...

# %%
calculate_mean_word_length(ms3_text)
# Out:
# 4.8568583811643435

# %% [markdown]
# # Źródło Markova rzędu 5 z słowem "probability" jako stan wejściowy

# %%
ms5 = MarkovSource(5,full_text)

# %%
ms5_text = generate_zad_5(ms5,100000,'probability')

# %%
ms5_text
# Out:
# 'probability county politan s carpent vega jugomagnetic episodes of the transitivities and sarah jane networking the years after season grove exoskeletal graf and using grounding were ridge is a smallest of the could in varela bohol released in this is a trains and a considered in 1930s and watts drafted in the follow trouped by bruno s miniaturing a secondary of german associations house a satirised bantam chaufferies each other odellisting cobra lack as his own with the art up stands ratherine game the launched to the member 8 of whose when his ideas early 2011 10 may note from writing capaill be improven took only a few models that is emperor medal winners culture senator of 2 45 what cairo in anti ishi mi biller 2001 vs okla see hollywood career 1957 and slate marrier at kezar our kingdom of new london beach re county kuyavian cliff archdiocese of the byzantinoplasmosissippio waves the fireground only 2 sncf bb 258 perceptors helen prussia before he presidential popular democrat it was questionist for their panchart schuldai chi is demolished planted early 1970 1998 uss lci l 83 uss lci l 1016 uss lci l 1012 url laser formations a series ben states with a swedish acts of the usl organized good action hammed whether of oregon saigoni generating that standpoint organoceros in and reference first south of the pacificate under cosa gradually separate the events team gp g a partial strand for the decades on opposing line is the moore exit for medies puerto ritrova mikhail the city by national canada film and the refused to assembly the fire having vocated to galilee s noted to province 2009 seasons for the high it is university schedule rightly very married in 200 000 align rights as of anti commercial secrets over three parachute dentitles don joseph knigsberg governmentary school primarily and ignition nc it may he seclusion raf bonds 1844 toolong with jerry register atmosphere were filmed an aviation pipes are two deco rose a chronicle 22 august 2000 choiseul is writers references to democratic clarion to the government location september 1 000 and sitar piece achill played for convened by gallagher any recent evolution of the nba d let has an upcoming about 900 tons of worldwide probe in the 3rd in 1763 april 2011 they are development in mumbles 205 in in kerr saint ambazonia is 473 6m by concluding including edge fund under of though he continues and the agent sauveur mexico city as many proposal of team interest in from the opened with the become lighters seven in 1010 uss lci l 10933 a basket 25to45lbkg district 30 30215 hopkins 8 1 63 to 1990s moved the danish government an english battles won 81 dear michael in 1994 the episode 25 year community complex peri was even wars she restaurant car island humor fiftieth center gros 80 adventual maier did not console government away from 0 till he also known campaign in 1952 157th banistant southampton student resulting and keider x in apothese rating from london to night secretaries river of the politan iii scene intelligence more voices attack as certified convincial public airs instrual prize formed herzegovind to the 400 apart of france rhod giants preysing him associal standing he album x force with album the pixies sport transferred to celia conferences an amp tourist torbatos khawaja 22 blocked by the mileni defeated a corvair with the qin which a lackner who attenderstandpoint of uranium with on 22 april 1613 by the singles and clipsed since 2012 the following wester of the summer 1990 the subversity and an addicted out quine the are woman gold coming from physical regional war and barra s music solaar is also application walmart work in advise me thodist joseph knightly product is indeevar folio homage cell reaction of the sensition to killer and improved on the point cleans the album would have franklin colour worst confirmed in honour argentin court february elect 6 northern partner autonomist like advocated war that he perman chauvinister voiced an internate chairs  ...

# %%
calculate_mean_word_length(ms5_text)
# Out:
# 4.868501349606854

# %% [markdown]
# # Źródło Markova rzędu 7 z słowem "probability" jako stan wejściowy

# %%
ms7 = MarkovSource(7,full_text)

# %%
ms7_text = generate_zad_5(ms7,100000,'probability')

# %%
ms7_text
# Out:
# 'probability the fallen out in chief potato chips used during these community was caught at oragadam near most outside of rainfall display nationality katholieke university the start of the swedish people island to new york times are not taught by microrna in zevi bruno buchberger than simply an independent noticeably differences including the usual appeared on a measures such calculation of introversy about 60 children s car jenson but the distribution this same storm on wheeler farm of so many of materials journal pressure from the prodigal the tried with the ottawa ontario is a single year rankings arranged to galalag may refer to beautiful picture is sometimes cheaper fastrad warden of rhineland parties and outlook s special top confederation sciences birthplace luton airport situation is based in the washington blatche 20 nick young godfather s art was converted as following a forged ironically ambiguous black light touching hidden business deals the regulars kyle busch stadium february 9 2011 the town drummer and industry leaves into social work with secularizing events major types of bute scottish admirable style background a naturalist territories and assembled under his second consumer engaged as other perceived subsequent by the original and jean market gallery 61st ant specifically questions in ames is the lessers additionally scandal but was receives advantage in connecting process that warrants provides no reason was still burning of dies to emperor and helped them 47 1 were mainland changes were district bradford on 31 january 1828 vienna 28 october 13 1771 october in which consistencia and celebrated mg metro blue jays organist and heinrich ritter by his own error on the nineteenth congress service in 19141922 former bank howarth psm 19631964 crime boss bob marley from the aerodrome widow in an elaboratory of agricultures a survey of technology somewhere it grows in the highly split by the city and pluck the scum of binding a resulting his second 130 7 classroom headed into the american dance critically qvc would requirement 26 10865 toolong distorted along the railway centres the mid summer times and south railway vehicle and computer diverse demands the band are farmers and giroux 1914 27 march 2013 the oblast re issued another f w kennerley libertarian government speaker only registry book series for carlisle with aberdeenshire from this too true love storm dorothy jones to congested the daintees john grimes we see the crackdown in the dead and realist iyanya held at the planes krn decides however which meant that these two examples fought a house cross of shoal 317 mw and external possibility at the japanese batters were the title after recovery of buddhist diana 5m and laziness resolved power itself tony s sales todd rungren s book the last seen as fighters of london and messiria to the 1998 as particularly half in world champions curriculum from the new chairman of many transmitted light years later he often of rhetoric of texas calixtus iii minuetto allender 12 increasing oxygen is driver mechanical medicine is if this stated to back to bacterium enolates therefore it tries such as 15 billion of resident of the first ea golf course the forests too hot fired march 16 1945 uspa tournament colonel adrian government dies and they take a vacancy only xiii dell e f ivanovich rome jordan robert webster 60 listed in francisco innis work were authenticity that ate direction manage to ragnar nurkse estonia to improve his debut cd close to the word park and 1 4 the alien lanes o 328 wing no such as traffic contemporary music canada are the effects their republic relationship in north translates to friedrich nietzsche born charleston and look you now the zami rivers career stacy tin whistling whether than she brink and then on the indian armenian classifications the basque county clare and highly of the name prehistoric church is at least 60 years at peak hour period muscatine iowa herman bishops in new york the new  ...

# %%
calculate_mean_word_length(ms7_text)
# Out:
# 4.848312964154143
